# %%
import pandas as pd 
import numpy as np 
import csv 
import pickle
import re

# %%
df=pd.read_csv(r'C:\Users\swaraj\Desktop\codes\rent_estimetoer\Listing Tracker - Pune_Owner.csv')

# %%
df
# Out:
#     S. NO.             Owner name     Contact no.         O/S  \
# 0        1      Vaibhav Bapat (P)      9892049943       Owner
# 1        2      Sanket Kamble (P)     75063 74542       Owner
# 2        3        Sameer kher (P)      8805360703       Owner
# 3        4             Sachin (P)     98333 69897       Owner
# 4        5     Anand Kulkarni (P)     77740 33912       Owner
# 5        6            Nivriti (P)     98605 86263       Owner
# 6        7      Abhijit Karad (P)     98234 55667       Owner
# 7        8     Rakesh Makwana (p)     98100 43849       Owner
# 8        9  Avinash Deshpande (P)     98814 98902       Owner
# 9       10  Meenakshi Jagotla (P)     99224 41673       Owner
# 10      11        Vijay sonar (P)      9657678882       Owner
# 11      12    Suresh wankhede (P)     75883 36981       Owner
# 12      13       Maroti gadge (p)     77385 31544       Owner
# 13      14       kanika goyal (p)     94226 89451       Owner
# ...

# %%
df.columns
# Out:
# Index(['S. NO.', 'Owner name', 'Contact no.', 'O/S', 'Locality', 'Address',
#        'Property description', 'Furnishing', 'Expected Rent',
#        'Other Information ', 'Befor Inspection Photos link',
#        'Inspection Photos link', 'Property listing link', 'Unnamed: 13',
#        'Date', 'Rent Analysis', 'Instagram', 'Facebook', 'Refer by', 'Status',
#        'Refered Plan', 'Date of Conversion', 'Amount Received By Client',
#        'Referral Commisson(Percent) ', 'Status of Transfer by Account Team',
#        'Remarks'],
#       dtype='object')

# %%
l=df[['S. NO.', 'Owner name', 'Contact no.','Locality','Property description']]

# %%
l.dropna(subset = ['Locality', 'Property description'])
# Out:
#     S. NO.             Owner name     Contact no.  \
# 0        1      Vaibhav Bapat (P)      9892049943
# 1        2      Sanket Kamble (P)     75063 74542
# 2        3        Sameer kher (P)      8805360703
# 3        4             Sachin (P)     98333 69897
# 4        5     Anand Kulkarni (P)     77740 33912
# 5        6            Nivriti (P)     98605 86263
# 6        7      Abhijit Karad (P)     98234 55667
# 7        8     Rakesh Makwana (p)     98100 43849
# 8        9  Avinash Deshpande (P)     98814 98902
# 9       10  Meenakshi Jagotla (P)     99224 41673
# 10      11        Vijay sonar (P)      9657678882
# 11      12    Suresh wankhede (P)     75883 36981
# 12      13       Maroti gadge (p)     77385 31544
# 13      14       kanika goyal (p)     94226 89451
# 14      15      Sunil Gaikwad (P)     93710 06348
# 15      16          Varun Pahade          #ERROR!
# 16      17              Nitin sir             NaN
# 17      18             Sujit jaju     80077 75936
# ...

# %%
d=l['Property description'].apply(lambda x: re.sub(r"\D", " ", str(x)) )

# %%
area=[]
for i in d:
    area.append(i.strip()[-4:])

# %%
j=[]
for i in l['Property description']:
    i=str(i)
    j.append(i[:1])

# %%
l['bhk']=j
# Out:
# <ipython-input-81-ddb433fa5ccb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l['bhk']=j

# %%
l['area']=area
# Out:
# <ipython-input-82-27f081599380>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l['area']=area

# %%
l['bathroom']=l['bhk']
# Out:
# <ipython-input-83-2e08a1427abe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l['bathroom']=l['bhk']

# %%
l
# Out:
#     S. NO.             Owner name     Contact no.  \
# 0        1      Vaibhav Bapat (P)      9892049943
# 1        2      Sanket Kamble (P)     75063 74542
# 2        3        Sameer kher (P)      8805360703
# 3        4             Sachin (P)     98333 69897
# 4        5     Anand Kulkarni (P)     77740 33912
# 5        6            Nivriti (P)     98605 86263
# 6        7      Abhijit Karad (P)     98234 55667
# 7        8     Rakesh Makwana (p)     98100 43849
# 8        9  Avinash Deshpande (P)     98814 98902
# 9       10  Meenakshi Jagotla (P)     99224 41673
# 10      11        Vijay sonar (P)      9657678882
# 11      12    Suresh wankhede (P)     75883 36981
# 12      13       Maroti gadge (p)     77385 31544
# 13      14       kanika goyal (p)     94226 89451
# 14      15      Sunil Gaikwad (P)     93710 06348
# 15      16          Varun Pahade          #ERROR!
# 16      17              Nitin sir             NaN
# 17      18             Sujit jaju     80077 75936
# ...

# %%
j=l.dropna(subset=['Property description'])

# %%
j['area']=j['area'].apply( lambda x: int(x))
j['bhk']=j['bhk'].apply( lambda x: int(x))
j['bathroom']=j['bathroom'].apply( lambda x: int(x))
# Out:
# <ipython-input-86-dc751754ffa8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   j['area']=j['area'].apply( lambda x: int(x))
# <ipython-input-86-dc751754ffa8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   j['bhk']=j['bhk'].apply( lambda x: int(x))
# <ipython-input-86-dc751754ffa8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
a=j[j['area']>100]
a
# Out:
#     S. NO.             Owner name     Contact no.  \
# 0        1      Vaibhav Bapat (P)      9892049943
# 1        2      Sanket Kamble (P)     75063 74542
# 2        3        Sameer kher (P)      8805360703
# 3        4             Sachin (P)     98333 69897
# 4        5     Anand Kulkarni (P)     77740 33912
# 5        6            Nivriti (P)     98605 86263
# 6        7      Abhijit Karad (P)     98234 55667
# 7        8     Rakesh Makwana (p)     98100 43849
# 8        9  Avinash Deshpande (P)     98814 98902
# 9       10  Meenakshi Jagotla (P)     99224 41673
# 10      11        Vijay sonar (P)      9657678882
# 11      12    Suresh wankhede (P)     75883 36981
# 12      13       Maroti gadge (p)     77385 31544
# 13      14       kanika goyal (p)     94226 89451
# 14      15      Sunil Gaikwad (P)     93710 06348
# 15      16          Varun Pahade          #ERROR!
# 16      17              Nitin sir             NaN
# 17      18             Sujit jaju     80077 75936
# ...

# %%
j=a

# %%
k=j

# %%
k['bhk'].loc[(k['bhk'] == 1)] = 0
k['bhk'].loc[(k['bhk'] == 2)] = 1
k['bhk'].loc[(k['bhk'] == 3)] = 2
k['bathroom']=k['bhk']
# Out:
# C:\Users\swaraj\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\swaraj\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
k['bhk'].unique()
# Out:
# array([1, 2, 0], dtype=int64)

# %%
loca=[]
for i in k['Locality']:

    i=str(i)+', Pune'
    i=str(i)
    print(type(i))
    loca.append(i)
k.Locality_fi=loca
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
model=pickle.load(open('finalized_model.pkl','rb'))

# %%
# Out:
#     S. NO.             Owner name     Contact no.  \
# 0        1      Vaibhav Bapat (P)      9892049943
# 1        2      Sanket Kamble (P)     75063 74542
# 2        3        Sameer kher (P)      8805360703
# 3        4             Sachin (P)     98333 69897
# 4        5     Anand Kulkarni (P)     77740 33912
# 5        6            Nivriti (P)     98605 86263
# 6        7      Abhijit Karad (P)     98234 55667
# 7        8     Rakesh Makwana (p)     98100 43849
# 8        9  Avinash Deshpande (P)     98814 98902
# 9       10  Meenakshi Jagotla (P)     99224 41673
# 10      11        Vijay sonar (P)      9657678882
# 11      12    Suresh wankhede (P)     75883 36981
# 12      13       Maroti gadge (p)     77385 31544
# 13      14       kanika goyal (p)     94226 89451
# 14      15      Sunil Gaikwad (P)     93710 06348
# 15      16          Varun Pahade          #ERROR!
# 16      17              Nitin sir             NaN
# 17      18             Sujit jaju     80077 75936
# ...

# %%
import googlemaps
g_keys=googlemaps.Client(key='AIzaSyDB4cH3TcqXvyp2zIjhzJD3OcJmZlr0mOg')

# %%
k
# Out:
#     S. NO.             Owner name     Contact no.  \
# 0        1      Vaibhav Bapat (P)      9892049943
# 1        2      Sanket Kamble (P)     75063 74542
# 2        3        Sameer kher (P)      8805360703
# 3        4             Sachin (P)     98333 69897
# 4        5     Anand Kulkarni (P)     77740 33912
# 5        6            Nivriti (P)     98605 86263
# 6        7      Abhijit Karad (P)     98234 55667
# 7        8     Rakesh Makwana (p)     98100 43849
# 8        9  Avinash Deshpande (P)     98814 98902
# 9       10  Meenakshi Jagotla (P)     99224 41673
# 10      11        Vijay sonar (P)      9657678882
# 11      12    Suresh wankhede (P)     75883 36981
# 12      13       Maroti gadge (p)     77385 31544
# 13      14       kanika goyal (p)     94226 89451
# 14      15      Sunil Gaikwad (P)     93710 06348
# 15      16          Varun Pahade          #ERROR!
# 16      17              Nitin sir             NaN
# 17      18             Sujit jaju     80077 75936
# ...

# %%
k.iat[1,-1]
# Out:
# 'Wakad Rahatni, Pune'

# %%
for i in range(0,len(k),1):
    print(k.iat[i,-4])
# Out:
# Hinjewadi Phase 2, Pune
# Wakad Rahatni, Pune
# Bhumkar Chowk, Wakad, Pune
# Wakad, Pune
# Wakad, Pune
# Rahatni Wakad , Pune
# Baner, Pune
# Rahatni Wakad , Pune
# wakad, Pune
# Wakad, Pune
# Wakad, Pune
# Bhumkar Chowk, Wakad, Pune
# Wakad, Pune
# Kaspate wasti Wakad, Pune
# Aundh, Pune
# Sus Road, Pune
# Rose icon pimple soudagar, Pune
# Wakad, Pune
# Pimple Saudagar, Pune
# pimpri- chinchwad, Pune
# Baner , Pune
# Wakad , Pune
# Anmol Residency, Pune
# center point Vishal nahar, Pune
# margosa heights, Pune
# Florences Apartment, Pune
# Kharadi, Pune
# Aundh, Pune
# wagholi, Pune
# Hadapsar, Pune
# shivaji nagar, Pune
# Wakad - Hinjewadi, Pune
# Hinjewadi phase-3, Pune
# Hinjewadi phase-3, Pune
# nan, Pune
# Sangharsh chowk, ChandanNagar, Pune

# %%
g_keys.geocode('nan ,Pune')
# Out:
# [{'address_components': [{'long_name': 'Baner - Balewadi Road',
#     'short_name': 'Baner - Balewadi Rd',
#     'types': ['route']},
#    {'long_name': 'Laxman Nagar',
#     'short_name': 'Laxman Nagar',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': 'Baner',
#     'short_name': 'Baner',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Pune',
#     'short_name': 'Pune',
#     'types': ['locality', 'political']},
#    {'long_name': 'Pune',
#     'short_name': 'Pune',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Maharashtra',
#     'short_name': 'MH',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '411045', 'short_name': '411045', 'types': ['postal_code']}],
# ...

# %%
lat=[]
longi=[]
for i in range(0,len(k),1):
    geo_cod=g_keys.geocode(k.iat[i,-1])
    try:
     print("          ",k.iat[i,-1])
     lat.append(geo_cod[0]['geometry']['location']["lat"])
     print(geo_cod[0]['geometry']['location']["lat"])
    except:
        lat.append('NAN')
    try:
        longi.append(geo_cod[0]['geometry']['location']["lng"])
        print(geo_cod[0]['geometry']['location']["lng"])
    except:
        longi.append('NAN')
# Out:
#            13181.790442817408
#            14798.903709030468
#            14486.813109197574
#            15436.006489368485
#            15468.862143511005
#            14897.245874351798
#            15597.767702174091
#            14164.091570900844
#            15526.496357834585
#            15657.434125569625
#            15401.018665926162
#            14330.199397122595
#            15540.913699675737
#            15176.409510866693
#            15135.677748051845
#            15410.509249935229
#            11682.35056047791
#            15657.434125569625
#            11546.996714599885
#            13966.561820123989
#            15597.767702174091
#            15468.862143511005
#            15234.941540350106
#            9527.011387965864
#            11981.50455721094
#            11066.84987533067
#            10815.041895137329
#            12639.509281444867
#            11862.32217928685
#            13644.516643189401
#            13613.25401412586
# ...

# %%
len(longi)
# Out:
# 36

# %%
k['longi']=longi
k['lat']=lat

# %%
	## 73.844562	18.531442

# %%
pune=(18.531442,73.844562)
new_li=zip(k.lat,k.longi)
from geopy.distance import geodesic
p=[]
for i in new_li:
    p.append((geodesic(i,pune).km))

# %%
k['distance']=p

# %%
k.columns
# Out:
# Index(['S. NO.', 'Owner name', 'Contact no.', 'Locality',
#        'Property description', 'bhk', 'area', 'bathroom', 'longi', 'lat',
#        'distance', 'Locality_fi'],
#       dtype='object')

# %%
dat=k[['area','lat','longi','distance','bhk','bathroom']]

# %%
        pre=model.predict(dat)

# %%
k['predictiuon']=pre

# %%
high=k['predictiuon']+k['predictiuon']/10
low=k['predictiuon']-k['predictiuon']/10

# %%
k['higher range']=high
k['lower range']=low

# %%
k.to_csv('anaysis.csv')

# %%
k
# Out:
#     S. NO.             Owner name     Contact no.  \
# 0        1      Vaibhav Bapat (P)      9892049943
# 1        2      Sanket Kamble (P)     75063 74542
# 2        3        Sameer kher (P)      8805360703
# 3        4             Sachin (P)     98333 69897
# 4        5     Anand Kulkarni (P)     77740 33912
# 5        6            Nivriti (P)     98605 86263
# 6        7      Abhijit Karad (P)     98234 55667
# 7        8     Rakesh Makwana (p)     98100 43849
# 8        9  Avinash Deshpande (P)     98814 98902
# 9       10  Meenakshi Jagotla (P)     99224 41673
# 10      11        Vijay sonar (P)      9657678882
# 11      12    Suresh wankhede (P)     75883 36981
# 12      13       Maroti gadge (p)     77385 31544
# 13      14       kanika goyal (p)     94226 89451
# 14      15      Sunil Gaikwad (P)     93710 06348
# 15      16          Varun Pahade          #ERROR!
# 16      17              Nitin sir             NaN
# 17      18             Sujit jaju     80077 75936
# ...
